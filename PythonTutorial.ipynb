# %% [markdown]
# # A Python for Data Science Tutorial
#
# ### By Michael Albuqerque 04/06/2108
#
# For this tutorial, we will be using the Cereals Data Found [here](https://perso.telecom-paristech.fr/eagan/class/igr204/datasets). More information about it can be found [Here on Kaggle](https://www.kaggle.com/crawford/80-cereals)
#
# Pandas is extremely well documented. There is also a tutorial within the documentation. This is probably the best place to start to figure out for eg. what the suitable operation is and the corresponding syntax: [Pandas Documentation Tutorials](https://pandas.pydata.org/pandas-docs/stable/tutorials.html)
#
# If you are also an R user, a good way to understand the equivalent R and pandas operations lies in [this page of the documentation.](http://pandas.pydata.org/pandas-docs/stable/comparison_with_r.html)
#
# We will start out by importing the pandas library to reading in the csv dataset.

# %%
import pandas as pd

df = pd.read_csv('cereal1.csv')

# %% [markdown]
# This will work if the notebook and the csv file are in the same directory. If not, specify the full path of the file like so:
#
# df = pd.read_csv('~/PycharmProjects/PythonTutorial/cereal1.csv')
#
# Let's examine the type of 'df'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# df is a dataframe object and it still supports base python operations like len()

# %%
len(df)
# Out:
# 77

# %% [markdown]
# Or print(). This will print the whole dataset.

# %%
print(df)
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# ...

# %% [markdown]
# It also has its own functions and methods.
#
# Shape gives the number of rows and columns.
# Head allows you to examine the first *n* rows of the dataset.

# %%
df.shape
# Out:
# (77, 16)

# %%
df.head(5)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# Let's examine the dataset with a statistical summary by calling the describe method and check for missing data.

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# We can also check the datatypes of each column with dtypes

# %%
df.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %% [markdown]
# And examine a column

# %%
df['carbo']
# Out:
# 0      5.0
# 1      8.0
# 2      7.0
# 3      8.0
# 4     14.0
# 5     10.5
# 6     11.0
# 7     18.0
# 8     15.0
# 9     13.0
# 10    12.0
# 11    17.0
# 12    13.0
# 13    13.0
# 14    12.0
# 15    22.0
# 16    21.0
# 17    13.0
# 18    12.0
# 19    10.0
# 20    21.0
# 21    21.0
# 22    11.0
# 23    18.0
# 24    11.0
# 25    14.0
# 26    14.0
# 27    12.0
# 28    14.0
# 29    13.0
#       ...
# 47    15.0
# 48    15.0
# 49    21.0
# 50    18.0
# 51    13.5
# 52    11.0
# 53    20.0
# 54    13.0
# 55    10.0
# 56    14.0
# 57    -1.0
# 58    14.0
# 59    10.5
# 60    15.0
# 61    23.0
# 62    22.0
# 63    16.0
# 64    19.0
# 65    20.0
# 66     9.0
# 67    16.0
# 68    15.0
# 69    21.0
# 70    15.0
# 71    16.0
# 72    21.0
# 73    13.0
# 74    17.0
# 75    17.0
# 76    16.0
# Name: carbo, Length: 77, dtype: float64

# %% [markdown]
# For multiple columns use *iloc* while acessing by index

# %%
df.iloc[:,[1,2,3,4]]
# Out:
#    mfr type  calories  protein
# 0    N    C        70        4
# 1    Q    C       120        3
# 2    K    C        70        4
# 3    K    C        50        4
# 4    R    C       110        2
# 5    G    C       110        2
# 6    K    C       110        2
# 7    G    C       130        3
# 8    R    C        90        2
# 9    P    C        90        3
# 10   Q    C       120        1
# 11   G    C       110        6
# 12   G    C       120        1
# 13   G    C       110        3
# 14   G    C       110        1
# 15   R    C       110        2
# 16   K    C       100        2
# 17   K    C       110        1
# 18   G    C       110        1
# 19   K    C       110        3
# 20   N    H       100        3
# 21   K    C       110        2
# 22   G    C       100        2
# 23   R    C       100        2
# 24   K    C       110        2
# 25   K    C       110        1
# 26   K    C       100        3
# 27   P    C       120        3
# 28   K    C       120        3
# ...

# %% [markdown]
# or use *loc* to access by column name.

# %%
df.loc[:, ['rating', 'carbo']]
# Out:
#        rating  carbo
# 0   68.402973    5.0
# 1   33.983679    8.0
# 2   59.425505    7.0
# 3   93.704912    8.0
# 4   34.384843   14.0
# 5   29.509541   10.5
# 6   33.174094   11.0
# 7   37.038562   18.0
# 8   49.120253   15.0
# 9   53.313813   13.0
# 10  18.042851   12.0
# 11  50.764999   17.0
# 12  19.823573   13.0
# 13  40.400208   13.0
# 14  22.736446   12.0
# 15  41.445019   22.0
# 16  45.863324   21.0
# 17  35.782791   13.0
# 18  22.396513   12.0
# 19  40.448772   10.0
# 20  64.533816   21.0
# 21  46.895644   21.0
# 22  36.176196   11.0
# 23  44.330856   18.0
# 24  32.207582   11.0
# 25  31.435973   14.0
# 26  58.345141   14.0
# 27  40.917047   12.0
# 28  41.015492   14.0
# 29  28.025765   13.0
# ..        ...    ...
# 47  40.105965   15.0
# 48  29.924285   15.0
# 49  40.692320   21.0
# 50  59.642837   18.0
# 51  30.450843   13.5
# 52  37.840594   11.0
# 53  41.503540   20.0
# 54  60.756112   13.0
# 55  63.005645   10.0
# 56  49.511874   14.0
# 57  50.828392   -1.0
# ...

# %% [markdown]
# We can sort by one or more rows using *sort_values*

# %%
df.sort_values(['rating', 'carbo'], ascending=False)
# Out:
#                                  name mfr type  calories  protein  fat  \
# 3           All-Bran with Extra Fiber   K    C        50        4    0
# 64             Shredded Wheat 'n'Bran   N    C        90        3    0
# 65          Shredded Wheat spoon size   N    C        90        3    0
# 0                           100% Bran   N    C        70        4    1
# 63                     Shredded Wheat   N    C        80        2    0
# 20             Cream of Wheat (Quick)   N    H       100        3    0
# 55                       Puffed Wheat   Q    C        50        2    0
# 54                        Puffed Rice   Q    C        50        1    0
# 50                  Nutri-grain Wheat   K    C        90        3    0
# 2                            All-Bran   K    C        70        4    1
# 68            Strawberry Fruit Wheats   N    C        90        2    0
# 26                Frosted Mini-Wheats   K    C       100        3    0
# ...

# %% [markdown]
# Pandas also supports chaining meaning that you can perform an operation and then another operation on the output of the first option.
#
# Here I am going to *groupby* the manufacturer *mfr*, get the mean of all cereals within each meanufacturer and then sort by carbohydrates (in ascending order)

# %%
df.groupby('mfr').agg({'carbo': 'mean'}).sort_values('carbo')
# Out:
#          carbo
# mfr
# Q    10.000000
# P    13.222222
# G    14.727273
# K    15.130435
# A    16.000000
# N    16.000000
# R    17.625000

# %% [markdown]
# Let's get rid of the outliers with sugar,carb or potassium counts <0

# %%
df = df.loc[df.sugars >= 0]

# %%
df = df.loc[df.potass >= 0]

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   74.000000  74.000000  74.000000   74.000000  74.000000  74.000000
# mean   107.027027   2.513514   1.000000  162.364865   2.175676  14.729730
# std     19.843893   1.075802   1.006826   82.769787   2.423391   3.891675
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  135.000000   0.250000  12.000000
# 50%    110.000000   2.500000   1.000000  180.000000   2.000000  14.500000
# 75%    110.000000   3.000000   1.000000  217.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  74.000000   74.000000   74.000000  74.000000  74.000000  74.000000
# mean    7.108108   98.513514   29.054054   2.216216   1.030811   0.821622
# std     4.359111   70.878681   22.294352   0.832067   0.153416   0.235715
# ...

# %% [markdown]
# ## Exploratory Data Visualization
#
# Now that we know a little about our data and once we have it in a clean and organized state, let's generate some visualizations.
#
# Correlation is a good place to start understanding relationship between variables.

# %%
corr = df.corr()
corr
# Out:
#           calories   protein       fat    sodium     fiber     carbo  \
# calories  1.000000  0.019066  0.498610  0.300649 -0.293413  0.250681
# protein   0.019066  1.000000  0.208431 -0.054674  0.500330 -0.130864
# fat       0.498610  0.208431  1.000000 -0.005407  0.016719 -0.318043
# sodium    0.300649 -0.054674 -0.005407  1.000000 -0.070675  0.355983
# fiber    -0.293413  0.500330  0.016719 -0.070675  1.000000 -0.356083
# carbo     0.250681 -0.130864 -0.318043  0.355983 -0.356083  1.000000
# sugars    0.562340 -0.329142  0.270819  0.101451 -0.141205 -0.331665
# potass   -0.066609  0.549407  0.193279 -0.032603  0.903374 -0.349685
# vitamins  0.265356  0.007335 -0.031156  0.361477 -0.032243  0.258148
# shelf     0.097234  0.133865  0.263691 -0.069719  0.297539 -0.101790
# weight    0.696091  0.216158  0.214625  0.308576  0.247226  0.135136
# cups      0.087200 -0.244469 -0.175892  0.119665 -0.513061  0.363932
# rating   -0.689376  0.470618 -0.409284 -0.401295  0.584160  0.052055
#
# ...

# %% [markdown]
# But this isn't easy to instantly recognize what the big and small numbers are without plotting them. Let's try it with matplotlib.

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.matshow(corr)

# %% [markdown]
# Not ideal. We can tweak the plot to show exactly what we want, but there's an even easier way. Let's try it with seaborn, a library built on top of matplotlib.

# %%
import seaborn as sns
sns.heatmap(corr)

# %% [markdown]
# Let's try a *distplot*, a distribution plot or a histogram of the ratings.

# %%
sns.distplot(df['rating'])

# %%
sns.boxplot(x="mfr", y="rating", data=df)

# %%
df.loc[df.rating >= 90]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3    8.0       0     330        25      3     1.0   0.5  93.704912

# %% [markdown]
# ### Simple Machine Learning

# %%
import statsmodels.formula.api as smf

model = smf.ols(formula= "rating ~ calories + protein + fat + sodium + fiber + carbo + sugars + potass" ,data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 rating   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.994
# Method:                 Least Squares   F-statistic:                     1455.
# Date:                Fri, 06 Apr 2018   Prob (F-statistic):           2.63e-69
# Time:                        16:44:18   Log-Likelihood:                -105.89
# No. Observations:                  73   AIC:                             229.8
# Df Residuals:                      64   BIC:                             250.4
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     56.3086      0.997     56.474      0.000      54.317      58.300
# ...

# %% [markdown]
# # Still to come - sklearn
#
# Feature Selection
# Standardization of variables
